# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\martin.wambugu\Downloads\WLD_RTFP_country_2024-01-25\WLD_RTFP_country_2024-01-25.csv")
df
# Out:
#       Open  High   Low  Close  Inflation      country ISO3        date
# 0     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-01-01
# 1     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-02-01
# 2     0.54  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-03-01
# 3     0.53  0.55  0.53   0.55        NaN  Afghanistan  AFG  2007-04-01
# 4     0.56  0.57  0.56   0.57        NaN  Afghanistan  AFG  2007-05-01
# ...    ...   ...   ...    ...        ...          ...  ...         ...
# 6979  2.94  2.97  2.91   2.91      -3.50  Yemen, Rep.  YEM  2023-09-01
# 6980  2.93  2.96  2.90   2.93      -1.81  Yemen, Rep.  YEM  2023-10-01
# 6981  2.96  2.99  2.93   2.99       2.88  Yemen, Rep.  YEM  2023-11-01
# 6982  3.05  3.08  3.02   3.07       8.15  Yemen, Rep.  YEM  2023-12-01
# 6983  3.12  3.15  3.05   3.05       8.43  Yemen, Rep.  YEM  2024-01-01
#
# [6984 rows x 8 columns]

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Inflation
# count  6905.000000  6905.000000  6905.000000  6905.000000  6473.000000
# mean      1.401762     1.437902     1.367398     1.401935    12.688761
# std       3.927775     4.083691     3.768386     3.902194    33.023182
# min       0.010000     0.010000     0.010000     0.010000   -31.690000
# 25%       0.790000     0.800000     0.780000     0.790000    -0.700000
# 50%       0.960000     0.980000     0.950000     0.970000     4.450000
# 75%       1.110000     1.130000     1.090000     1.110000    14.550000
# max      79.540000    81.300000    78.090000    81.300000   366.800000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6984 entries, 0 to 6983
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       6905 non-null   float64
#  1   High       6905 non-null   float64
#  2   Low        6905 non-null   float64
#  3   Close      6905 non-null   float64
#  4   Inflation  6473 non-null   float64
#  5   country    6984 non-null   object
#  6   ISO3       6984 non-null   object
#  7   date       6984 non-null   object
# dtypes: float64(5), object(3)
# memory usage: 436.6+ KB

# %%
#split date column to show year, month and day
df[['Year','Month','Date']] = df['date'].str.split('-', expand=True)
df
# Out:
#       Open  High   Low  Close  Inflation      country ISO3        date  Year  \
# 0     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-01-01  2007
# 1     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-02-01  2007
# 2     0.54  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007-03-01  2007
# 3     0.53  0.55  0.53   0.55        NaN  Afghanistan  AFG  2007-04-01  2007
# 4     0.56  0.57  0.56   0.57        NaN  Afghanistan  AFG  2007-05-01  2007
# ...    ...   ...   ...    ...        ...          ...  ...         ...   ...
# 6979  2.94  2.97  2.91   2.91      -3.50  Yemen, Rep.  YEM  2023-09-01  2023
# 6980  2.93  2.96  2.90   2.93      -1.81  Yemen, Rep.  YEM  2023-10-01  2023
# 6981  2.96  2.99  2.93   2.99       2.88  Yemen, Rep.  YEM  2023-11-01  2023
# 6982  3.05  3.08  3.02   3.07       8.15  Yemen, Rep.  YEM  2023-12-01  2023
# 6983  3.12  3.15  3.05   3.05       8.43  Yemen, Rep.  YEM  2024-01-01  2024
#
#      Month Date
# 0       01   01
# ...

# %%
#drop the unecessary column date
df = df.drop(columns = 'date')
df
# Out:
#       Open  High   Low  Close  Inflation      country ISO3  Year Month Date
# 0     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007    01   01
# 1     0.53  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007    02   01
# 2     0.54  0.54  0.53   0.53        NaN  Afghanistan  AFG  2007    03   01
# 3     0.53  0.55  0.53   0.55        NaN  Afghanistan  AFG  2007    04   01
# 4     0.56  0.57  0.56   0.57        NaN  Afghanistan  AFG  2007    05   01
# ...    ...   ...   ...    ...        ...          ...  ...   ...   ...  ...
# 6979  2.94  2.97  2.91   2.91      -3.50  Yemen, Rep.  YEM  2023    09   01
# 6980  2.93  2.96  2.90   2.93      -1.81  Yemen, Rep.  YEM  2023    10   01
# 6981  2.96  2.99  2.93   2.99       2.88  Yemen, Rep.  YEM  2023    11   01
# 6982  3.05  3.08  3.02   3.07       8.15  Yemen, Rep.  YEM  2023    12   01
# 6983  3.12  3.15  3.05   3.05       8.43  Yemen, Rep.  YEM  2024    01   01
#
# [6984 rows x 10 columns]

# %%
df.plot(x = 'Year', y = 'Inflation')
# Out:
# <Axes: xlabel='Year'>

# %%
#show data for Kenya only
df_kenya = df[df['country'].str.contains('Kenya')]
df_kenya
# Out:
#       Open  High   Low  Close  Inflation country ISO3  Year Month Date
# 2943  0.45  0.46  0.44   0.45        NaN   Kenya  KEN  2007    01   01
# 2944  0.45  0.46  0.44   0.44        NaN   Kenya  KEN  2007    02   01
# 2945  0.44  0.45  0.43   0.44        NaN   Kenya  KEN  2007    03   01
# 2946  0.44  0.45  0.43   0.45        NaN   Kenya  KEN  2007    04   01
# 2947  0.45  0.46  0.44   0.44        NaN   Kenya  KEN  2007    05   01
# ...    ...   ...   ...    ...        ...     ...  ...   ...   ...  ...
# 3143  1.81  1.85  1.77   1.82      39.12   Kenya  KEN  2023    09   01
# 3144  1.81  1.85  1.77   1.85      33.99   Kenya  KEN  2023    10   01
# 3145  1.84  1.88  1.80   1.85      28.12   Kenya  KEN  2023    11   01
# 3146  1.84  1.88  1.80   1.81      22.75   Kenya  KEN  2023    12   01
# 3147  1.79  1.84  1.75   1.82      15.28   Kenya  KEN  2024    01   01
#
# [205 rows x 10 columns]

# %%
#line graph of Kenya's rate of inflation 
df_kenya.plot(x='Year', y = 'Inflation', title = "Kenya's rate of Inflation from 2007 - 2023")
# Out:
# <Axes: title={'center': "Kenya's rate of Inflation from 2007 - 2023"}, xlabel='Year'>

# %%
df[df['country'].str.contains('Kenya')]
for x in df.
